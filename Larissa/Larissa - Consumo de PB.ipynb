# %% [markdown]
# # 1. Leitura dos dados

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
def imprimirAnaliseGrafica(y_test, preds, model):
    import seaborn as sns
    import matplotlib.pyplot as plt
    # %matplotlib inline
    # Plot de dispersão
    plt.figure(figsize=(12,6))
    plt.title("Dipersão dos dados reais vs predições usando " + type(model).__name__)
    sns.scatterplot(x=y_test.index, y=y_test, label="Real")
    sns.scatterplot(x=y_test.index, y=preds, label="Predito")
    plt.figure(figsize=(12,6))
    plt.title("Real vs Predito usando " + type(model).__name__)
    # Plot de regressão
    sns.regplot(x=y_test, y=preds)
    plt.xlabel("Real")
    plt.ylabel("Predito")
    plt.legend(["Ponto","R² = " + str("%.2f"%r2_score(y_test, preds))])

# %%
# Leitura dos dados em uma variável DataFrame
df =  pd.read_excel('../Datasets/Larissa/Consumo de Proteina - Larissa MD04.xlsx')

# %%
df
# Out:
#      Código Master  Experimento     Vaca  Produção de leite  Consumo de PB  \
# 0              101            1  ALECRIM              20.37         0.1687
# 1              102            1    ANETE              33.93         0.1688
# 2              103            1    CLARA              26.57         0.1692
# 3              104            1   CLARIS              19.46         0.1690
# 4              105            1    DARYA              27.40         0.1690
# ..             ...          ...      ...                ...            ...
# 224            554            5    NANDI              43.20         0.1535
# 225            555            5  OPERETA              26.80         0.1534
# 226            556            5  PORANGA              20.30         0.1535
# 227            557            5  SOLANGE              30.60         0.1536
# 228            558            5  TRINKET              23.20         0.1535
#
# ...

# %%
y = df['Consumo de PB']
X = df.iloc[:, 5:]

# %%
X
# Out:
#      12493199  12489342  12485485  12481628  12477771  12473913  12470056  \
# 0    0.686458  0.683910  0.681005  0.682385  0.687912  0.690693  0.687556
# 1    0.658517  0.660127  0.661341  0.663315  0.664639  0.664055  0.660349
# 2    0.687373  0.685893  0.687533  0.689194  0.690112  0.690191  0.688474
# 3    0.686180  0.685498  0.686096  0.687771  0.687481  0.684123  0.680639
# 4    0.684966  0.683662  0.686932  0.691391  0.691930  0.690160  0.689059
# ..        ...       ...       ...       ...       ...       ...       ...
# 224  0.703588  0.702210  0.704943  0.708891  0.710013  0.708551  0.706441
# 225  0.654562  0.654260  0.655371  0.656218  0.654426  0.653395  0.655519
# 226  0.677057  0.678620  0.679245  0.678900  0.678581  0.678916  0.678966
# 227  0.690044  0.688782  0.688125  0.687499  0.687846  0.690248  0.690756
# 228  0.693361  0.692763  0.693917  0.695704  0.696731  0.696284  0.696740
#
#      12466199  12462342  12458485  ...  4034543   4030686   4026829   \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.3)

# %% [markdown]
# # 2. Testes

# %% [markdown]
# ## Random Forrest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_model = RandomForestRegressor(random_state=0)

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
rf_preds = rf_model.predict(X_test)

# %%
print(mean_absolute_error(y_test, rf_preds))
# Out:
# 0.006747311111111103

# %%
imprimirAnaliseGrafica(y_test, rf_preds, rf_model)

# %% [markdown]
# ## Regressão Linear

# %%
from sklearn import linear_model

# %%
ln_model = linear_model.LinearRegression()

# %%
ln_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
ln_preds = ln_model.predict(X_test)

# %%
print(mean_absolute_error(y_test, ln_preds))
# Out:
# 47716.91723712396

# %%
imprimirAnaliseGrafica(y_test, ln_preds, ln_model)

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn import linear_model

# %%
rd_model = linear_model.Ridge(alpha=.5)

# %%
rd_model.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.5)

# %%
rd_preds = rd_model.predict(X_test)

# %%
print(mean_absolute_error(y_test, rd_preds))
# Out:
# 0.008033674336673407

# %%
imprimirAnaliseGrafica(y_test, rd_preds, rd_model)

# %% [markdown]
# ## Lasso

# %%
from sklearn import linear_model

# %%
rd_model = linear_model.Lasso(alpha=.5)

# %%
rd_model.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.5)

# %%
rd_preds = rd_model.predict(X_test)

# %%
print(mean_absolute_error(y_test, rd_preds))
# Out:
# 0.010120036231884056

# %%
imprimirAnaliseGrafica(y_test, rd_preds, rd_model)

# %% [markdown]
# ## Elastic Net

# %%
from sklearn import linear_model

# %%
rd_model = linear_model.ElasticNet(alpha=0.01, l1_ratio=0.1, max_iter=10000000)

# %%
rd_model.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=0.01, l1_ratio=0.1, max_iter=10000000)

# %%
rd_preds = rd_model.predict(X_test)

# %%
print(mean_absolute_error(y_test, rd_preds))
# Out:
# 0.010234390591589445

# %%
imprimirAnaliseGrafica(y_test, rd_preds, rd_model)

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVR

# %%
svm_model = SVR()

# %%
svm_model.fit(X_train, y_train)
# Out:
# SVR()

# %%
svm_preds = svm_model.predict(X_test)

# %%
print(mean_absolute_error(y_test, svm_preds))
# Out:
# 0.010598550724637681

# %%
svm_preds
# Out:
# array([0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696,
#        0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696,
#        0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696,
#        0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696,
#        0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696,
#        0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696,
#        0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696,
#        0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696, 0.1696,
#        0.1696, 0.1696, 0.1696, 0.1696, 0.1696])

# %%
imprimirAnaliseGrafica(y_test, svm_preds, svm_model)

# %% [markdown]
# ## XGBRegressor

# %%
from xgboost import XGBRegressor

# %%
xgb_model = XGBRegressor()

# %%
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
xgb_preds =  xgb_model.predict(X_test)

# %%
print(mean_absolute_error(y_test, xgb_preds))
# Out:
# 0.007016846792075942

# %%
imprimirAnaliseGrafica(y_test, xgb_preds, xgb_model)
